# %%
import os
import numpy as np
import pandas as pd

# %%
ls
# Out:
#  Volume in drive D is Storage
#  Volume Serial Number is B6BC-1F3F
#
#  Directory of D:\Code\pcmy
#
# 19/07/2018  04:56 PM    <DIR>          .
# 19/07/2018  04:56 PM    <DIR>          ..
# 19/07/2018  01:19 PM    <DIR>          .ipynb_checkpoints
# 19/07/2018  04:56 PM            87,728 concatenate_files.ipynb
# 19/07/2018  04:02 PM    <DIR>          debundled
# 18/07/2018  06:38 PM             3,902 pcsg_shopify_debundled.py
# 12/07/2018  03:34 PM             5,558 pcsg_shopify_requests.py
# 19/07/2018  04:07 PM    <DIR>          shopify_files
# 19/07/2018  04:11 PM             3,391 shopify_files_combine_debundle.py
# 16/07/2018  03:50 PM             4,074 shopify_inventory_snapshot.py
# 18/07/2018  06:37 PM           593,152 shopify_my_requests (playground).ipynb
#                6 File(s)        697,805 bytes
#                5 Dir(s)  699,339,091,968 bytes free

# %%
from glob import glob
df = pd.concat([pd.read_csv(x, 
                            parse_dates=['Paid at', 'Created at'], 
                            date_parser=lambda x: pd.to_datetime(x.rpartition('+')[0])
                           ) for x in glob('shopify_files/*.csv')], 
               ignore_index=True)

# df_2 = df[['Name', 'Email', 'Paid at', 'Created at']].drop_duplicates()
# df_2[df_2['Created at'] >= "2018-07-17"]

# %%
df
# Out:
#            Name                          Email Financial Status  \
# 0     #PCMY2543   alicia_qing1110@yahoo.com.my       authorized
# 1     #PCMY2543   alicia_qing1110@yahoo.com.my              NaN
# 2     #PCMY2543   alicia_qing1110@yahoo.com.my              NaN
# 3     #PCMY2542             liliannk@gmail.com             paid
# 4     #PCMY2542             liliannk@gmail.com              NaN
# 5     #PCMY2542             liliannk@gmail.com              NaN
# 6     #PCMY2542             liliannk@gmail.com              NaN
# 7     #PCMY2541   bossbeautynail3851@gmail.com             paid
# 8     #PCMY2540             tenniech@gmail.com             paid
# 9     #PCMY2540             tenniech@gmail.com              NaN
# 10    #PCMY2540             tenniech@gmail.com              NaN
# 11    #PCMY2539             farhah76@yahoo.com             paid
# 12    #PCMY2538      shu.hsien@khazanah.com.my             paid
# 13    #PCMY2537         sombresmiley@gmail.com             paid
# ...

# %%
glob('pcmy/shopify_files/*.csv')
# Out:
# []

# %%
df_2 = df.drop_duplicates()
df_2.to_csv('df_2.csv')#.Name.value_counts()

# %%
df.drop_duplicates()#.Name.value_counts()
# Out:
#          Name                          Email Financial Status  \
# 0   #PCMY2543   alicia_qing1110@yahoo.com.my       authorized
# 1   #PCMY2543   alicia_qing1110@yahoo.com.my              NaN
# 2   #PCMY2543   alicia_qing1110@yahoo.com.my              NaN
# 3   #PCMY2542             liliannk@gmail.com             paid
# 4   #PCMY2542             liliannk@gmail.com              NaN
# 5   #PCMY2542             liliannk@gmail.com              NaN
# 6   #PCMY2542             liliannk@gmail.com              NaN
# 7   #PCMY2541   bossbeautynail3851@gmail.com             paid
# 8   #PCMY2540             tenniech@gmail.com             paid
# 9   #PCMY2540             tenniech@gmail.com              NaN
# 10  #PCMY2540             tenniech@gmail.com              NaN
# 11  #PCMY2539             farhah76@yahoo.com             paid
# 12  #PCMY2538      shu.hsien@khazanah.com.my             paid
# 13  #PCMY2537         sombresmiley@gmail.com             paid
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-ba25f3189123> in <module>()
#       8                             parse_dates=['Paid at', 'Created at'],
#       9                             date_parser=lambda x: pd.to_datetime(x.rpartition('+')[0]),
# ---> 10                             dtype={'Lineitem sku': 'str', 'Name': 'str'}) for x in os.listdir('shopify_files')],ignore_index=True)
#
# <ipython-input-19-ba25f3189123> in <listcomp>(.0)
#       8                             parse_dates=['Paid at', 'Created at'],
#       9                             date_parser=lambda x: pd.to_datetime(x.rpartition('+')[0]),
# ---> 10                             dtype={'Lineitem sku': 'str', 'Name': 'str'}) for x in os.listdir('shopify_files')],ignore_index=True)
#
# ...

# %%
os.listdir('shopify_files')[0]
# Out:
# 'orders_export - Copy.csv'

# %%
glob('shopify_files\*.csv')[0]
# Out:
# 'shopify_files\\orders_export - Copy.csv'
